# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\user\Downloads\data set with questions\data set with questions\Weather Data.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0     01-01-2012 00:00    -1.3              -3.5         18                9
# 1     01-01-2012 01:00     7.4               2.8         20               24
# 2     01-01-2012 02:00    15.7              13.4         21               26
# 3     01-01-2012 03:00     4.9              -2.6         27               15
# 4     01-01-2012 04:00   -13.4             -19.7         30                4
# ...                ...     ...               ...        ...              ...
# 8779    9/30/2012 5:00     1.4              -3.7         97               22
# 8780    9/30/2012 6:00    -4.6              -9.5         98               11
# 8781    9/30/2012 7:00     1.5              -6.3         99               30
# 8782    9/30/2012 8:00    -6.3             -13.5         99               15
# 8783    9/30/2012 9:00    24.5              14.7        100               11
#
# ...

# %%
data.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  01-01-2012 00:00    -1.3              -3.5         18                9
# 1  01-01-2012 01:00     7.4               2.8         20               24
# 2  01-01-2012 02:00    15.7              13.4         21               26
# 3  01-01-2012 03:00     4.9              -2.6         27               15
# 4  01-01-2012 04:00   -13.4             -19.7         30                4
#
#    Visibility_km  Press_kPa        Weather
# 0           25.0      98.67          Clear
# 1           24.1      99.37           Rain
# 2           25.0      99.84         Cloudy
# 3           24.1     100.94   Mainly Clear
# 4           25.0     102.32  Mostly Cloudy

# %%
data.tail()
# Out:
#            Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  9/30/2012 5:00     1.4              -3.7         97               22
# 8780  9/30/2012 6:00    -4.6              -9.5         98               11
# 8781  9/30/2012 7:00     1.5              -6.3         99               30
# 8782  9/30/2012 8:00    -6.3             -13.5         99               15
# 8783  9/30/2012 9:00    24.5              14.7        100               11
#
#       Visibility_km  Press_kPa        Weather
# 8779           48.3     100.16         Cloudy
# 8780           48.3     101.46  Mostly Cloudy
# 8781           24.1     101.48          Clear
# 8782           24.1     101.90         Cloudy
# 8783           25.0     102.98  Mostly Cloudy

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# ### 1. Find all the unique 'Wind Speed' values in the data.

# %%
data["Wind Speed_km/h"].unique()
# Out:
# array([ 9, 24, 26, 15,  4,  0, 19, 17, 11, 22, 35, 13, 20,  6,  7, 30, 32,
#        41, 39, 28, 44, 33, 37, 52, 46,  2, 50, 48, 57, 63, 43, 83, 70, 54],
#       dtype=int64)

# %%
data["Wind Speed_km/h"].nunique
# Out:
# 34

# %% [markdown]
# ### 2. Find the number of times when the 'Weather is exactly Clear'.

# %%
data.loc[data['Weather']=='Clear','Weather'].value_counts()
# Out:
# Weather
# Clear    1326
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Find the number of times when the 'Wind Speed was exactly 4 km/h'.

# %%
data.loc[data['Wind Speed_km/h']==4,'Wind Speed_km/h'].value_counts()
# Out:
# Wind Speed_km/h
# 4    474
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Find out all the Null Values in the data.

# %%
data.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# ### 5. Rename the column name 'Weather' of the dataframe to 'Weather Condition'.

# %%
dc=data.rename(columns={'Weather': 'Weather Condition'})

# %%
dc.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather Condition'],
#       dtype='object')

# %% [markdown]
# ### 6. What is the mean 'Visibility' ?

# %%
data['Visibility_km'].mean()
# Out:
# 27.664446721311478

# %% [markdown]
# ### 7. What is the Standard Deviation of 'Pressure' in this data?

# %%
data['Press_kPa'].std()
# Out:
# 0.8440047459486483

# %% [markdown]
# ### 8. What is the Variance of 'Relative Humidity' in this data ?

# %%
data['Rel Hum_%'].var()
# Out:
# 286.248550198502

# %% [markdown]
# ### 9. Find all instances when 'Snow' was recorded.

# %%
d=data.rename(columns={'Weather Condition': 'Weather'},inplace=True)

# %%
data.loc[data['Weather']=='Snow',['Date/Time','Weather']]
# Out:
#              Date/Time Weather
# 11    01-01-2012 11:00    Snow
# 70    03-01-2012 22:00    Snow
# 73    04-01-2012 01:00    Snow
# 105   05-01-2012 09:00    Snow
# 112   05-01-2012 16:00    Snow
# ...                ...     ...
# 8573   9/22/2012 13:00    Snow
# 8650   9/25/2012 18:00    Snow
# 8671   9/26/2012 15:00    Snow
# 8713    9/28/2012 1:00    Snow
# 8734    9/28/2012 8:00    Snow
#
# [390 rows x 2 columns]

# %% [markdown]
# ### 10. Find all instances when 'Wind Speed is above 24' and 'Visibility is 25'.

# %%
data.loc[(data['Wind Speed_km/h']>24) & (data['Visibility_km']==25),['Wind Speed_km/h','Visibility_km']]
# Out:
#       Wind Speed_km/h  Visibility_km
# 2                  26           25.0
# 73                 35           25.0
# 126                39           25.0
# 158                26           25.0
# 184                44           25.0
# ...               ...            ...
# 8707               33           25.0
# 8714               26           25.0
# 8738               28           25.0
# 8745               28           25.0
# 8776               43           25.0
#
# [308 rows x 2 columns]

# %% [markdown]
# ### 11. What is the Mean value of each column against each 'Weather Condition ?

# %%
g=data.groupby('Weather')
g.mean(numeric_only=True)
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# ### 12. What is the Minimum & Maximum value of each column against each 'Weather Condition ?

# %%
g.min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather
# Clear                                    01-01-2012 00:00   -23.3
# Cloudy                                   01-01-2012 02:00   -21.4
# Drizzle                                  01-06-2012 08:00     1.1
# Drizzle,Fog                              01-04-2012 01:00     0.0
# Drizzle,Ice Pellets,Fog                    7/24/2012 5:00     0.4
# Drizzle,Snow                             05-02-2012 09:00     0.9
# Drizzle,Snow,Fog                         03-11-2012 20:00     0.3
# Fog                                      01-01-2012 13:00   -16.0
# Freezing Drizzle                         04-01-2012 03:00    -9.0
# Freezing Drizzle,Fog                      10/15/2012 4:00    -6.4
# Freezing Drizzle,Haze                    01-06-2012 00:00    -5.8
# Freezing Drizzle,Snow                    02-06-2012 07:00    -8.3
# Freezing Fog                              12/31/2012 2:00   -19.0
# ...

# %%
g.max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather
# Clear                                      9/30/2012 7:00    32.8
# Cloudy                                     9/30/2012 8:00    30.5
# Drizzle                                   9/15/2012 22:00    18.8
# Drizzle,Fog                               9/19/2012 15:00    19.9
# Drizzle,Ice Pellets,Fog                    7/24/2012 5:00     0.4
# Drizzle,Snow                               3/17/2012 1:00     1.2
# Drizzle,Snow,Fog                          9/21/2012 12:00     1.1
# Fog                                       9/30/2012 19:00    20.8
# Freezing Drizzle                           8/21/2012 5:00    -2.3
# Freezing Drizzle,Fog                       7/26/2012 6:00    -0.3
# Freezing Drizzle,Haze                      5/21/2012 4:00    -5.0
# Freezing Drizzle,Snow                      8/18/2012 4:00    -3.3
# Freezing Fog                               5/14/2012 9:00    -0.1
# ...

# %% [markdown]
# ### 13. Show all the Records where Weather Condition is Fog.

# %%
pd.DataFrame(data.loc[data['Weather']=='Fog','Weather'])
# Out:
#      Weather
# 13       Fog
# 53       Fog
# 136      Fog
# 197      Fog
# 278      Fog
# ...      ...
# 8475     Fog
# 8511     Fog
# 8518     Fog
# 8537     Fog
# 8771     Fog
#
# [150 rows x 1 columns]

# %% [markdown]
# ### 14. Find all instances when 'Weather is Clear' or 'Visibility is above 40'.

# %%
data.loc[(data['Weather']=='Clear') | (data['Visibility_km']>40),['Weather','Visibility_km']]
# Out:
#             Weather  Visibility_km
# 0             Clear           25.0
# 9             Clear           48.3
# 16            Clear           25.0
# 17     Mainly Clear           48.3
# 18           Cloudy           48.3
# ...             ...            ...
# 8774  Mostly Cloudy           48.3
# 8777   Mainly Clear           48.3
# 8779         Cloudy           48.3
# 8780  Mostly Cloudy           48.3
# 8781          Clear           24.1
#
# [3027 rows x 2 columns]

# %% [markdown]
# ### 15. Find all instances when :
# A. 'Weather is Clear' and 'Relative Humidity is greater than 50' or
#
# B. 'Visibility is above 40'

# %%
data.loc[(data['Weather']=='Clear')&(data['Rel Hum_%']>50)|(data['Visibility_km']>40),['Weather','Rel Hum_%','Visibility_km']]
# Out:
#             Weather  Rel Hum_%  Visibility_km
# 9             Clear         35           48.3
# 17     Mainly Clear         42           48.3
# 18           Cloudy         42           48.3
# 19            Clear         43           48.3
# 23     Mainly Clear         45           48.3
# ...             ...        ...            ...
# 8774  Mostly Cloudy         92           48.3
# 8777   Mainly Clear         95           48.3
# 8779         Cloudy         97           48.3
# 8780  Mostly Cloudy         98           48.3
# 8781          Clear         99           24.1
#
# [2864 rows x 3 columns]
